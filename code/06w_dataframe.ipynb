# %% [markdown]
# <a href="https://colab.research.google.com/github/naugim26/2026-BDA/blob/main/code/06w_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 06 테이블 분석 패키지 pandas

# %% [markdown]
# ## 일부 내용은 code 05파일에 함께 있음

# %% [markdown]
# ### 6.2

# %%
import pandas as pd
import numpy as np

dates = pd.date_range("20260408",periods=6)
dates
# Out:
# DatetimeIndex(['2026-04-08', '2026-04-09', '2026-04-10', '2026-04-11',
#                '2026-04-12', '2026-04-13'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates[0]
# Out:
# Timestamp('2026-04-08 00:00:00')

# %%
dates=pd.date_range("20260408",end='20250420')
dates
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %%
dates=pd.date_range("20260408",periods=6,freq='3D')
dates
# Out:
# DatetimeIndex(['2026-04-08', '2026-04-11', '2026-04-14', '2026-04-17',
#                '2026-04-20', '2026-04-23'],
#               dtype='datetime64[ns]', freq='3D')

# %%
dates=pd.date_range("20260408",periods=6,freq='3H')
dates
# Out:
# /tmp/ipykernel_1688/1145539086.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dates=pd.date_range("20260408",periods=6,freq='3H')
# DatetimeIndex(['2026-04-08 00:00:00', '2026-04-08 03:00:00',
#                '2026-04-08 06:00:00', '2026-04-08 09:00:00',
#                '2026-04-08 12:00:00', '2026-04-08 15:00:00'],
#               dtype='datetime64[ns]', freq='3h')

# %%
dates=pd.date_range("20260408",periods=6,freq='W')
dates
# Out:
# DatetimeIndex(['2026-04-12', '2026-04-19', '2026-04-26', '2026-05-03',
#                '2026-05-10', '2026-05-17'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
dates=pd.date_range("20260408",periods=6,freq='W-SUN')
dates
# Out:
# DatetimeIndex(['2026-04-12', '2026-04-19', '2026-04-26', '2026-05-03',
#                '2026-05-10', '2026-05-17'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
dates=pd.date_range("20260408",periods=6,freq='W-THU')
dates
# Out:
# DatetimeIndex(['2026-04-09', '2026-04-16', '2026-04-23', '2026-04-30',
#                '2026-05-07', '2026-05-14'],
#               dtype='datetime64[ns]', freq='W-THU')

# %%
dates=pd.date_range("20260408",periods=6,freq='W-FRI')
dates
# Out:
# DatetimeIndex(['2026-04-10', '2026-04-17', '2026-04-24', '2026-05-01',
#                '2026-05-08', '2026-05-15'],
#               dtype='datetime64[ns]', freq='W-FRI')

# %%
dates=pd.date_range("20260408",periods=6,freq='M')
dates
# Out:
# /tmp/ipykernel_1688/3191251365.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates=pd.date_range("20260408",periods=6,freq='M')
# DatetimeIndex(['2026-04-30', '2026-05-31', '2026-06-30', '2026-07-31',
#                '2026-08-31', '2026-09-30'],
#               dtype='datetime64[ns]', freq='ME')

# %%
dates=pd.date_range("20260408",periods=6,freq='MS')
dates
# Out:
# DatetimeIndex(['2026-05-01', '2026-06-01', '2026-07-01', '2026-08-01',
#                '2026-09-01', '2026-10-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
dates=pd.date_range("20260408",periods=6)
dates
# Out:
# DatetimeIndex(['2026-04-08', '2026-04-09', '2026-04-10', '2026-04-11',
#                '2026-04-12', '2026-04-13'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2026-04-08 -0.508051 -1.005478 -0.431791  0.416017
# 2026-04-09  0.639638  0.714740 -0.691073 -0.447090
# 2026-04-10  0.433363  0.927475  0.964796 -0.098681
# 2026-04-11 -0.800079 -0.491462 -0.764113  0.079275
# 2026-04-12 -0.787063 -0.314054 -1.633578  0.670088
# 2026-04-13  0.101439  0.396464 -0.365115  0.558277

# %%
df2=pd.DataFrame({
    "A":1.0,
    "B":pd.Timestamp("20260408"),
    "C":pd.Series(np.arange(1,3,.5)),
    "D":np.array([3]*4,dtype="int32"),
    "E":pd.Categorical(["test","train","test","train"]),
    "F":"foo"
})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2026-04-08  1.0  3   test  foo
# 1  1.0 2026-04-08  1.5  3  train  foo
# 2  1.0 2026-04-08  2.0  3   test  foo
# 3  1.0 2026-04-08  2.5  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float64
# D            int32
# E         category
# F           object
# dtype: object

# %% [markdown]
# ### 6.3 DataFrame의 다양한 참조

# %%
import pandas as pd
pf=pd.DataFrame(data=[[25,35,8,18],
                      [18,27,10,20],
                      [17,17,10,19],
                      [12,22,9,20],
                      [22,34,8,16]],
                index=['윤일형','강수희','홍소희','유한빈','신수빈'],
                columns=['중간','기말','과제','출석'])
pf
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 강수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20
# 신수빈  22  34   8  16

# %%
pf['중간']
# Out:
# 윤일형    25
# 강수희    18
# 홍소희    17
# 유한빈    12
# 신수빈    22
# Name: 중간, dtype: int64

# %%
pf.중간
# Out:
# 윤일형    25
# 강수희    18
# 홍소희    17
# 유한빈    12
# 신수빈    22
# Name: 중간, dtype: int64

# %%
pf['출석']
# Out:
# 윤일형    18
# 강수희    20
# 홍소희    19
# 유한빈    20
# 신수빈    16
# Name: 출석, dtype: int64

# %%
pf[['출석']]
# Out:
#      출석
# 윤일형  18
# 강수희  20
# 홍소희  19
# 유한빈  20
# 신수빈  16

# %%
pf[['기말','출석','중간']]
# Out:
#      기말  출석  중간
# 윤일형  35  18  25
# 강수희  27  20  18
# 홍소희  17  19  17
# 유한빈  22  20  12
# 신수빈  34  16  22

# %%
pf[['기말']]
# Out:
#      기말
# 윤일형  35
# 강수희  27
# 홍소희  17
# 유한빈  22
# 신수빈  34

# %%
pf['중간']>20
# Out:
# 윤일형     True
# 강수희    False
# 홍소희    False
# 유한빈    False
# 신수빈     True
# Name: 중간, dtype: bool

# %%
pf[pf['중간']>20]
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 신수빈  22  34   8  16

# %%
pf[pf['출석']>=19]
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20

# %%
pf[(pf['출석']>=19) & (pf['기말'] >= 20)]
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20
# 유한빈  12  22   9  20

# %%
import pandas as pd
pf=pd.DataFrame(data=[[25,35,8,18],
                      [18,27,10,20],
                      [17,17,10,19],
                      [12,22,9,20],
                      [22,34,8,16]],
                index=['윤일형','강수희','홍소희','유한빈','신수빈'],
                columns=['중간','기말','과제','출석'])
pf
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 강수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20
# 신수빈  22  34   8  16

# %%
import pandas as pd
#df.loc[]
pf.loc['윤일형']
# Out:
# 중간    25
# 기말    35
# 과제     8
# 출석    18
# Name: 윤일형, dtype: int64

# %%
pf.loc[['윤일형']]
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18

# %%
pf.loc[['홍소희','윤일형']]
# Out:
#      중간  기말  과제  출석
# 홍소희  17  17  10  19
# 윤일형  25  35   8  18

# %%
pf.loc['윤일형':'유한빈']
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 강수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20

# %%
pf.loc[pf.중간>20]
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18
# 신수빈  22  34   8  16

# %%
pf.loc[(pf.중간>10) & (pf.과제 == 10)]
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20
# 홍소희  17  17  10  19

# %%
pf.loc[pf.index[0]]
# Out:
# 중간    25
# 기말    35
# 과제     8
# 출석    18
# Name: 윤일형, dtype: int64

# %%
pf.loc[[pf.index[0]]]
# Out:
#      중간  기말  과제  출석
# 윤일형  25  35   8  18

# %%
pf.loc[pf.index[1:4]]
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20

# %%
pf.loc[pf.index[1:4]][['기말','과제']]
# Out:
#      기말  과제
# 강수희  27  10
# 홍소희  17  10
# 유한빈  22   9

# %%
pf.loc[:,'과제']
# Out:
# 윤일형     8
# 강수희    10
# 홍소희    10
# 유한빈     9
# 신수빈     8
# Name: 과제, dtype: int64

# %%
pf.loc[:,'중간':'과제']
# Out:
#      중간  기말  과제
# 윤일형  25  35   8
# 강수희  18  27  10
# 홍소희  17  17  10
# 유한빈  12  22   9
# 신수빈  22  34   8

# %%
pf.loc[:,['기말','출석']]
# Out:
#      기말  출석
# 윤일형  35  18
# 강수희  27  20
# 홍소희  17  19
# 유한빈  22  20
# 신수빈  34  16

# %%
pf.loc[:,pf.columns[0]]
# Out:
# 윤일형    25
# 강수희    18
# 홍소희    17
# 유한빈    12
# 신수빈    22
# Name: 중간, dtype: int64

# %%
pf.loc[:,[pf.columns[0]]]
# Out:
#      중간
# 윤일형  25
# 강수희  18
# 홍소희  17
# 유한빈  12
# 신수빈  22

# %%
pf.loc[:,pf.columns[1:]]
# Out:
#      기말  과제  출석
# 윤일형  35   8  18
# 강수희  27  10  20
# 홍소희  17  10  19
# 유한빈  22   9  20
# 신수빈  34   8  16

# %%
pf.loc[:,pf.columns[1:3]]
# Out:
#      기말  과제
# 윤일형  35   8
# 강수희  27  10
# 홍소희  17  10
# 유한빈  22   9
# 신수빈  34   8

# %%
pf.loc[:,pf.columns[1:]][['기말','과제']]
# Out:
#      기말  과제
# 윤일형  35   8
# 강수희  27  10
# 홍소희  17  10
# 유한빈  22   9
# 신수빈  34   8

# %%
pf.loc['윤일형','출석']
# Out:
# np.int64(18)

# %%
pf.loc['윤일형':'유한빈','기말']
# Out:
# 윤일형    35
# 강수희    27
# 홍소희    17
# 유한빈    22
# Name: 기말, dtype: int64

# %%
pf.loc['윤일형':'유한빈','기말':'과제']
# Out:
#      기말  과제
# 윤일형  35   8
# 강수희  27  10
# 홍소희  17  10
# 유한빈  22   9

# %%
pf.loc[pf.index[0],pf.columns[1]]
# Out:
# np.int64(35)

# %%
pf.loc[pf.index[0:3],pf.columns[2]]
# Out:
# 윤일형     8
# 강수희    10
# 홍소희    10
# Name: 과제, dtype: int64

# %%
pf.loc[pf.index[0:3],pf.columns[2:]]
# Out:
#      과제  출석
# 윤일형   8  18
# 강수희  10  20
# 홍소희  10  19

# %%
pf.iloc[1]
# Out:
# 중간    18
# 기말    27
# 과제    10
# 출석    20
# Name: 강수희, dtype: int64

# %%
pf.iloc[[1]]
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20

# %%
pf.iloc[[1,3]]
# Out:
#      중간  기말  과제  출석
# 강수희  18  27  10  20
# 유한빈  12  22   9  20

# %%
pf.iloc[2:]
# Out:
#      중간  기말  과제  출석
# 홍소희  17  17  10  19
# 유한빈  12  22   9  20
# 신수빈  22  34   8  16

# %%
pf.iloc[:,2]
# Out:
# 윤일형     8
# 강수희    10
# 홍소희    10
# 유한빈     9
# 신수빈     8
# Name: 과제, dtype: int64

# %%
pf.iloc[:,[2]]
# Out:
#      과제
# 윤일형   8
# 강수희  10
# 홍소희  10
# 유한빈   9
# 신수빈   8

# %%
pf.iloc[:,1:]
# Out:
#      기말  과제  출석
# 윤일형  35   8  18
# 강수희  27  10  20
# 홍소희  17  10  19
# 유한빈  22   9  20
# 신수빈  34   8  16

# %%
pf.iloc[1,1]
# Out:
# np.int64(27)

# %%
pf.iloc[1:3,1:]
# Out:
#      기말  과제  출석
# 강수희  27  10  20
# 홍소희  17  10  19

# %%
pf.iloc[:,1:]
# Out:
#      기말  과제  출석
# 윤일형  35   8  18
# 강수희  27  10  20
# 홍소희  17  10  19
# 유한빈  22   9  20
# 신수빈  34   8  16

# %%
pf.iloc[[1,3,4],1:]
# Out:
#      기말  과제  출석
# 강수희  27  10  20
# 유한빈  22   9  20
# 신수빈  34   8  16

# %%
pf.iloc[[1,3,4],[0,1]]
# Out:
#      중간  기말
# 강수희  18  27
# 유한빈  12  22
# 신수빈  22  34

# %%
pf.at['윤일형','과제']
# Out:
# np.int64(8)

# %%
pf.at['유한빈','기말']
# Out:
# np.int64(22)

# %%
pf.at[pf.index[1],'출석']
# Out:
# np.int64(20)

# %%
pf.at[pf.index[3],pf.columns[2]]
# Out:
# np.int64(9)

# %%
pf.iat[1,2]
pf.iat[2,3]
# Out:
# np.int64(19)
