# %% [markdown]
# <a href="https://colab.research.google.com/github/naugim26/2026-BDA/blob/main/code/07w_dataframe_pydataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### 7.2 데이터프레임 정렬과 수정

# %%
#df.head(n)

# %%
#sort 행 으로 정

# %%
#열 추가
import numpy as np
import pandas as pd

s1 = pd.Series([1,2,3,4,5],index=pd.date_range("20240102",periods=5))
s1
# Out:
# 2024-01-02    1
# 2024-01-03    2
# 2024-01-04    3
# 2024-01-05    4
# 2024-01-06    5
# Freq: D, dtype: int64

# %%
df["E"] = s1
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2302/2693838969.py in <cell line: 0>()
# ----> 1 df["E"] = s1
#       2 df
#
# NameError: name 'df' is not defined

# %%
df = pd.DataFrame([[np.nan,2,np.nan,0],
                   [3,4,np.nan,1],
                   [np.nan,np.nan,np.nan,np.nan],
                   [np.nan,3,np.nan,4]],
                  columns=list("ABCD"))
df
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
from IPython.display import display_html
def display_side_by_side(*args):
    """여러 데이터프레임 비교가 쉽게 옆쪽으로 표시한다"""
    html_str=''
    for df in args:
        html_str += df.to_html() + '&nbsp;'*4
    display_html(html_str.replace('table','table style="display:inline"'), raw=True)

# %%
display_side_by_side(df.fillna(10),df)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10.0</td>
#       <td>2.0</td>
#       <td>10.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.0</td>
#       <td>4.0</td>
#       <td>10.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10.0</td>
#       <td>3.0</td>
#       <td>10.0</td>
#       <td>4.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
# ...

# %%
df.fillna(10)
# Out:
#       A     B     C     D
# 0  10.0   2.0  10.0   0.0
# 1   3.0   4.0  10.0   1.0
# 2  10.0  10.0  10.0  10.0
# 3  10.0   3.0  10.0   4.0

# %%
df
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df.fillna(10,inplace=True)
df
# Out:
#       A     B     C     D
# 0  10.0   2.0  10.0   0.0
# 1   3.0   4.0  10.0   1.0
# 2  10.0  10.0  10.0  10.0
# 3  10.0   3.0  10.0   4.0

# %%
df.fillna('missing',axis=0)
# Out:
#          A        B        C        D
# 0  missing      2.0  missing      0.0
# 1      3.0      4.0  missing      1.0
# 2  missing  missing  missing  missing
# 3  missing      3.0  missing      4.0

# %%
df.fillna('missing',limit=1)
# Out:
#          A        B        C        D
# 0  missing      2.0  missing      0.0
# 1      3.0      4.0      NaN      1.0
# 2      NaN  missing      NaN  missing
# 3      NaN      3.0      NaN      4.0

# %%
df.fillna('missing',limit=1,axis=1)
# Out:
#          A    B        C    D
# 0  missing  2.0      NaN  0.0
# 1      3.0  4.0  missing  1.0
# 2  missing  NaN      NaN  NaN
# 3  missing  3.0      NaN  4.0

# %%
df.fillna('value',axis=0)
# Out:
#        A      B      C      D
# 0  value    2.0  value    0.0
# 1    3.0    4.0  value    1.0
# 2  value  value  value  value
# 3  value    3.0  value    4.0

# %%
# !pip show pydataset
# Out:
# Name: pydataset
# Version: 0.2.0
# Summary: Provides instant access to many popular datasets right from Python (in dataframe structure).
# Home-page: https://github.com/iamaziz/PyDataset
# Author: Aziz Alto
# Author-email: iamaziz.alto@gmail.com
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: pandas
# Required-by:

# %%
# !pip install pydataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 82.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939415 sha256=f4a9dd6b12ed2d839851e5776d5d6d6b4daf7025cc274952b7d295869bcd7c3b
#   Stored in directory: /root/.cache/pip/wheels/4c/82/ad/f04abc617222b10438b1285ab9b5cfaecd180c10a7c81cff54
# Successfully built pydataset
# ...

# %%
from pydataset import data
all_data = data()
all_data
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dataset_id  757 non-null    object
#  1   title       757 non-null    object
# dtypes: object(2)
# memory usage: 12.0+ KB

# %%
all_data.describe()
# Out:
#        dataset_id                                         title
# count         757                                           757
# unique        727                                           702
# top       Hedonic  Seven data sets showing a bifactor solution.
# freq            2                                             8

# %%
df = data('titanic', show_doc = True)
# Out:
# titanic
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## titanic
#
# ### Description
#
# The data is an observation-based version of the 1912 Titanic passenger
# survival log,
#
# ### Usage
#
#     data(titanic)
#
# ### Format
#
# A data frame with 1316 observations on the following 4 variables.
#
# `class`
#
# a factor with levels `1st class` `2nd class` `3rd class` `crew`
#
# `age`
#
# a factor with levels `child` `adults`
#
# `sex`
#
# a factor with levels `women` `man`
#
# `survived`
#
# a factor with levels `no` `yes`
#
# ### Details
#
# titanic is saved as a data frame. Used to assess risk ratios
#
# ### Source
#
# Found in many other texts
#
# ### References
#
# Hilbe, Joseph M (2014), Modeling Count Data, Cambridge University Press Hilbe,
# Joseph M (2007, 2011), Negative Binomial Regression, Cambridge University
# Press Hilbe, Joseph M (2009), Logistic Regression Models, Chapman & Hall/CRC
#
# ### Examples
#
# ...

# %%
df = data('titanic')
df
# Out:
#           class     age    sex survived
# 1     1st class  adults    man      yes
# 2     1st class  adults    man      yes
# 3     1st class  adults    man      yes
# 4     1st class  adults    man      yes
# 5     1st class  adults    man      yes
# ...         ...     ...    ...      ...
# 1312  3rd class   child  women       no
# 1313  3rd class   child  women       no
# 1314  3rd class   child  women       no
# 1315  3rd class   child  women       no
# 1316  3rd class   child  women       no
#
# [1316 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1316 entries, 1 to 1316
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   class     1316 non-null   object
#  1   age       1316 non-null   object
#  2   sex       1316 non-null   object
#  3   survived  1316 non-null   object
# dtypes: object(4)
# memory usage: 51.4+ KB

# %%
df.describe()
# Out:
#             class     age   sex survived
# count        1316    1316  1316     1316
# unique          3       2     2        2
# top     3rd class  adults   man       no
# freq          706    1207   869      817

# %%
all_data[all_data.title.str.contains('car')]
# Out:
#     dataset_id  \
# 382        mpg
#
#                                                                  title
# 382  Fuel economy data from 1999 and 2008 for 38 popular models of car

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.13.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: matplotlib, numpy, pandas
# Required-by: missingno, segregation, splot

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 63.8 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib
# %config lnlineBackend.figure_format = 'retina'

# %%
df_mpg = data('mpg')
df_mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
df_mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
plt.rcParams['figure.figsize'] = [5,3]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df_mpg['manufacturer'])
plt.xticks(rotation=90)
plt.show()

# %%
# 다양한 파일 읽어오기
import pandas as pd
titanic = pd.read_excel('titanic.xlsx',index_col=0)
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 153.4+ KB

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
titanic.describe(include='all') #모든 컬럼
#unique,top,freq>문자열
# Out:
#              pclass     survived              name   sex          age  \
# count   1309.000000  1309.000000              1309  1309  1046.000000
# unique          NaN          NaN              1307     2          NaN
# top             NaN          NaN  Kelly, Mr. James  male          NaN
# freq            NaN          NaN                 2   843          NaN
# mean       2.294882     0.381971               NaN   NaN    29.881135
# std        0.837836     0.486055               NaN   NaN    14.413500
# min        1.000000     0.000000               NaN   NaN     0.166700
# 25%        2.000000     0.000000               NaN   NaN    21.000000
# 50%        3.000000     0.000000               NaN   NaN    28.000000
# 75%        3.000000     1.000000               NaN   NaN    39.000000
# max        3.000000     1.000000               NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# ...

# %%
titanic.to_csv('my_titanic.csv')

# %%
tt = pd.read_csv('my_titanic.csv',index_col=0)
tt.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
traffic = pd.read_csv("/content/2022년도시도별교통사고.csv",encoding='cp949')
traffic
# Out:
#    2022년도 시도별 교통사고 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0               시도    사고건수(건)    사망자수(명)    부상자수(명)
# 1               전국    196,836      2,735    281,803
# 2               서울     33,698        221     45,329
# 3               부산     10,882        113     14,829
# 4               경기     52,968        547     77,377
# 5               강원      6,425        139     10,160
# 6               충북      7,644        149     11,354
# 7               충남      8,164        230     11,964
# 8               전북      5,681        194      8,091
# 9               전남      8,335        201     12,611
# 10              경북     11,037        309     16,189
# 11              경남     10,611        258     14,545
# 12              제주      4,039         53      6,021
# 13              대구     11,102         68     15,721
# 14              인천      7,695         95     10,533
# 15              광주      7,122         58     10,722
# 16              대전      6,841         51      9,850
# ...

# %%
traffic = pd.read_csv("/content/2022년도시도별교통사고.csv",encoding='cp949',skiprows=1,index_col=0)
traffic
# Out:
#     사고건수(건) 사망자수(명)  부상자수(명)
# 시도
# 전국  196,836   2,735  281,803
# 서울   33,698     221   45,329
# 부산   10,882     113   14,829
# 경기   52,968     547   77,377
# 강원    6,425     139   10,160
# 충북    7,644     149   11,354
# 충남    8,164     230   11,964
# 전북    5,681     194    8,091
# 전남    8,335     201   12,611
# 경북   11,037     309   16,189
# 경남   10,611     258   14,545
# 제주    4,039      53    6,021
# 대구   11,102      68   15,721
# 인천    7,695      95   10,533
# 광주    7,122      58   10,722
# 대전    6,841      51    9,850
# 울산    3,660      32    5,177
# 세종      932      17    1,330

# %%
traffic.describe() #문자열로 인식
# Out:
#         사고건수(건) 사망자수(명)  부상자수(명)
# count        18      18       18
# unique       18      18       18
# top     196,836   2,735  281,803
# freq          1       1        1

# %%
traffic = pd.read_csv("/content/2022년도시도별교통사고.csv",encoding='cp949',skiprows=1,index_col=0,thousands=',')
traffic
# Out:
#     사고건수(건)  사망자수(명)  부상자수(명)
# 시도
# 전국   196836     2735   281803
# 서울    33698      221    45329
# 부산    10882      113    14829
# 경기    52968      547    77377
# 강원     6425      139    10160
# 충북     7644      149    11354
# 충남     8164      230    11964
# 전북     5681      194     8091
# 전남     8335      201    12611
# 경북    11037      309    16189
# 경남    10611      258    14545
# 제주     4039       53     6021
# 대구    11102       68    15721
# 인천     7695       95    10533
# 광주     7122       58    10722
# 대전     6841       51     9850
# 울산     3660       32     5177
# 세종      932       17     1330

# %%
traffic.describe()
# Out:
#              사고건수(건)      사망자수(명)        부상자수(명)
# count      18.000000    18.000000      18.000000
# mean    21870.666667   303.888889   31311.444444
# std     45378.932811   620.104914   64959.602563
# min       932.000000    17.000000    1330.000000
# 25%      6529.000000    60.500000    9927.500000
# 50%      7929.500000   144.000000   11659.000000
# 75%     10998.250000   227.750000   15498.000000
# max    196836.000000  2735.000000  281803.000000

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 전국 to 세종
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   사고건수(건)  18 non-null     int64
#  1   사망자수(명)  18 non-null     int64
#  2   부상자수(명)  18 non-null     int64
# dtypes: int64(3)
# memory usage: 576.0+ bytes

# %%
plt.rcParams['figure.figsize']
# Out:
# [5.0, 3.0]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.barplot(traffic)
plt.show()

# %%
plt.rcParams['font.family']
# Out:
# ['NanumGothic']

# %%
traffic['사망자수(명)'] # 특정 칼람
# Out:
# 시도
# 전국    2735
# 서울     221
# 부산     113
# 경기     547
# 강원     139
# 충북     149
# 충남     230
# 전북     194
# 전남     201
# 경북     309
# 경남     258
# 제주      53
# 대구      68
# 인천      95
# 광주      58
# 대전      51
# 울산      32
# 세종      17
# Name: 사망자수(명), dtype: int64

# %%
traffic[['사망자수(명)']]
# Out:
#     사망자수(명)
# 시도
# 전국     2735
# 서울      221
# 부산      113
# 경기      547
# 강원      139
# 충북      149
# 충남      230
# 전북      194
# 전남      201
# 경북      309
# 경남      258
# 제주       53
# 대구       68
# 인천       95
# 광주       58
# 대전       51
# 울산       32
# 세종       17

# %%
traffic[['사망자수(명)']].T
# Out:
# 시도         전국   서울   부산   경기   강원   충북   충남   전북   전남   경북   경남  제주  대구  인천  \
# 사망자수(명)  2735  221  113  547  139  149  230  194  201  309  258  53  68  95
#
# 시도       광주  대전  울산  세종
# 사망자수(명)  58  51  32  17

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.barplot(traffic[['사망자수(명)']].T)
plt.show()

# %%
traffic.columns[1]
# Out:
# '사망자수(명)'

# %%
traffic[[traffic.columns[1]]].T
# Out:
# 시도         전국   서울   부산   경기   강원   충북   충남   전북   전남   경북   경남  제주  대구  인천  \
# 사망자수(명)  2735  221  113  547  139  149  230  194  201  309  258  53  68  95
#
# 시도       광주  대전  울산  세종
# 사망자수(명)  58  51  32  17

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.barplot(traffic[[traffic.columns[1]]].T)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(4,3))
sns.barplot(traffic[[traffic.columns[1]]].T)
plt.xticks(rotation=90)
plt.show()

# %%
df_mpg.fl
# Out:
# 1      p
# 2      p
# 3      p
# 4      p
# 5      p
#       ..
# 230    p
# 231    p
# 232    p
# 233    p
# 234    p
# Name: fl, Length: 234, dtype: object

# %%
df_mpg.fl.value_counts()
# Out:
# fl
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: count, dtype: int64

# %%
df_mpg.fl.value_counts(ascending=True)
# Out:
# fl
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: count, dtype: int64

# %%
df_mpg['fl'].value_counts(ascending=True)
# Out:
# fl
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: count, dtype: int64
